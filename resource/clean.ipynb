# %%
import pandas as pd

# %%
df = pd.read_csv("./PalData.csv")

# %%
df = df[df["ElementType2"] == "EPalElementType::None"]

# %%
df
# Out:
#        1            Name       CodeName  Unnamed: 3 OverrideNameTextID  \
# 0      2          Anubis         Anubis         NaN                NaN
# 2      4  Incineram Noct  Baphomet_Dark         NaN                NaN
# 3      5             Mau         Bastet         NaN                NaN
# 4      6       Mau Cryst     Bastet_Ice         NaN                NaN
# 5      7         Rushoar           Boar         NaN                NaN
# ..   ...             ...            ...         ...                ...
# 131  133       Cinnamoth  CuteButterfly         NaN                NaN
# 134  136          Cremis        WoolFox         NaN                NaN
# 135  137           Dumud    LazyCatfish         NaN                NaN
# 136  138       Flambelle       LavaGirl         NaN                NaN
# 137  139           Rooby     FlameBambi         NaN                NaN
#
#      NamePrefixID OverridePartnerSkillTextID  IsPal  \
# 0             NaN                        NaN   True
# ...

# %%
df.to_csv("./PalDataSingleElement.csv", index=False)
